# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 1. pip install selenium
# 2. chrom 버전을 확인한다
# 3. chromdriver 다운로드 > 압축해제 > exe 파일을 꺼낸다
# 4. 파이썬소스와 같은 폴더에 exe 파일을 넣는다

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# alabaster                     0.7.12
# anaconda-client               1.11.0
# anaconda-navigator            2.3.2
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.6.6
# astropy                       5.1
# asttokens                     2.0.5
# async-generator               1.10
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome('C:\\Users\\daesi\\study_spark\\chromedriver_win32\\chromedriver.exe')

driver
# Out:
# C:\Users\daesi\AppData\Local\Temp\ipykernel_13900\2356695846.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:\\Users\\daesi\\study_spark\\chromedriver_win32\\chromedriver.exe')
# <selenium.webdriver.chrome.webdriver.WebDriver (session="2564df9bf0fb82eb8f452af1290cbe3e")>

# %%
from selenium.webdriver.common.by import By

url='http://www.google.com/ncr'
driver.get(url)

# %%
target = driver.find_element(By.CLASS_NAME,'gLFyf.gsfi')
target.send_keys('스파크')
target.send_keys(Keys.ENTER) #검색하기

# %%
driver.quit() #종료하기
