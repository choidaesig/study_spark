# %%
import urllib.request

#헤더 부분 정보 가져오기
res= urllib.request.urlopen('https://www.naver.com/') 
res.getheaders()
# Out:
# [('Server', 'NWS'),
#  ('Date', 'Mon, 31 Oct 2022 11:00:47 GMT'),
#  ('Content-Type', 'text/html; charset=UTF-8'),
#  ('Transfer-Encoding', 'chunked'),
#  ('Connection', 'close'),
#  ('Set-Cookie',
#   'PM_CK_loc=0235e18924804c1a1829080d609aafb35bb4c1d03fc9764218b440a83ef19176; Expires=Tue, 01 Nov 2022 11:00:47 GMT; Path=/; HttpOnly'),
#  ('Cache-Control', 'no-cache, no-store, must-revalidate'),
#  ('Pragma', 'no-cache'),
#  ('P3P',
#   'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"'),
#  ('X-Frame-Options', 'DENY'),
#  ('X-XSS-Protection', '1; mode=block'),
#  ('Strict-Transport-Security', 'max-age=63072000; includeSubdomains'),
#  ('Referrer-Policy', 'unsafe-url')]

# %%
# 바디 부분 정보 가져오기
print(res.read().decode('utf-8'))
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 
# ...

# %%
#인코딩 확인하기
import urllib.request

res= urllib.request.urlopen('https://www.naver.com/') 
encoding=res.info().get_content_charset()
encoding = 'utf-8' if encoding == None else encoding
test=res.read(200).decode(encoding)

test
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewpo'

# %%
import urllib.request
import urllib.parse

# GEt 방식 
param= urllib.parse.urlencode({'name':'홀길동' , 'age':10})
url = "http://unico2013.dothome.co.kr/crawling/get.php?%s" % param

res= urllib.request.urlopen(url) 



print(res.read().decode("utf-8"))
# Out:
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름은 홀길동이고 나이는 10이네요!!</h1>   </body>
# </html>

# %%
res.read()
# Out:
# b''

# %%
import urllib.request
import urllib.parse

# post 방식 
param= urllib.parse.urlencode({'name':'홀길동' , 'age':10})
url = "http://unico2013.dothome.co.kr/crawling/post.php?"
param = param.encode('ascii')

res= urllib.request.urlopen(url,param) 



print(res.read().decode("utf-8"))
# Out:
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 홀길동이고 나이는 10이네요!!</h1>   </body>
# </html>

# %% [markdown]
# # Requests 라이브러리를 이용한 호출

# %%
import requests

url = "http://unico2013.dothome.co.kr/crawling/exam.html"

res=requests.request('get',url)
res.encoding = 'utf-8'

res.text
# Out:
# '<!DOCTYPE html>\r\n<html>\r\n<head>\r\n<meta charset="UTF-8">\r\n<title>테스트</title>\r\n</head>\r\n<body>\r\n<h1>웹 크롤링을 테스트 합니다.</h1>\r\n</body>\r\n</html>'

# %%
import requests

url = "http://unico2013.dothome.co.kr/crawling/exam.html"

res=requests.request('post',url)
res.encoding = 'utf-8'

res.text
# Out:
# '<!DOCTYPE html>\r\n<html>\r\n<head>\r\n<meta charset="UTF-8">\r\n<title>테스트</title>\r\n</head>\r\n<body>\r\n<h1>웹 크롤링을 테스트 합니다.</h1>\r\n</body>\r\n</html>'

# %%
import requests

url_get = "http://unico2013.dothome.co.kr/crawling/get.php"
params= {'name':'홍길동','age': 20}

res = requests.request('get', url_get, params=params)
res.encoding = 'utf-8'
#res.url
res.text
# Out:
# '\ufeff<!DOCTYPE html>\r\n<html>\r\n  <head>\r\n    <meta charset="utf-8">\r\n    <title>POST TEST</title>\r\n  </head>\r\n  <body>\r\n   <h1>GET : 이름은 홍길동이고 나이는 20이네요!!</h1>   </body>\r\n</html>'

# %%
import requests

url_post = "http://unico2013.dothome.co.kr/crawling/post.php"
params= {'name':'길동무','age': 20}

res = requests.request('post', url_post, params=params)
res.encoding = 'utf-8'
#res.url
res.text
# Out:
# '\ufeff<!DOCTYPE html>\r\n<html>\r\n  <head>\r\n    <meta charset="utf-8">\r\n    <title>POST TEST</title>\r\n  </head>\r\n  <body>\r\n   <h1>POST : 이름과 나이를 전달해 주세요!!</h1>   </body>\r\n</html>'
